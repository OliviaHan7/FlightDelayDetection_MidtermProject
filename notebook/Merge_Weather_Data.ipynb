# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\bevli\Downloads\df_clean.csv", sep = ',')
jan2018_weather = pd.read_csv(r"C:\Users\bevli\Downloads\jan2018_weather.csv", sep = ',')
jan2019_weather = pd.read_csv(r"C:\Users\bevli\Downloads\jan2019_weather.csv", sep = ',')
jan2020_weather = pd.read_csv(r"C:\Users\bevli\Downloads\jan2020_weather.csv", sep = ',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13564/2005818602.py in <module>
#       2 jan2018_weather = pd.read_csv(r"C:\Users\bevli\Downloads\jan2018_weather.csv", sep = ',')
#       3 jan2019_weather = pd.read_csv(r"C:\Users\bevli\Downloads\jan2019_weather.csv", sep = ',')
# ----> 4 jan2020_weather = pd.read_csv(r"C:\Users\bevli\Downloads\jan2020_weather.csv", sep = ',')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\bevli\\Downloads\\jan2020_weather.csv'

# %%
jan2020_weather = pd.read_csv(r"C:\Users\bevli\Downloads\Midterm-project_I\jan2020_weather.csv", sep = ',')

# %%
#read test
data_test = pd.read_csv("df_flight_test.csv", sep = ',')

# %%
#remove headings within columns
jan2018_weather = jan2018_weather[jan2019_weather.date_time != 'date_time']
jan2019_weather = jan2019_weather[jan2019_weather.date_time != 'date_time']
jan2020_weather = jan2020_weather[jan2019_weather.date_time != 'date_time']
data.columns
# Out:
# C:\Users\bevli\AppData\Local\Temp/ipykernel_13564/4063444058.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   jan2020_weather = jan2020_weather[jan2019_weather.date_time != 'date_time']
# Index(['Unnamed: 0', 'fl_date', 'mkt_unique_carrier', 'branded_code_share',
#        'mkt_carrier', 'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num',
#        'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name',
#        'dest_airport_id', 'dest', 'dest_city_name', 'crs_dep_time', 'dep_time',
#        'dep_delay', 'taxi_out', 'wheels_off', 'wheels_on', 'taxi_in',
#        'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled', 'diverted', 'dup',
#        'crs_elapsed_time', 'actual_elapsed_time', 'air_time', 'flights',
#        'distance', 'arr_time_time', 'new'],
#       dtype='object')

# %%
#rename columns
jan2018_weather = jan2018_weather.rename(columns={'Aberdeen,+SD_maxtempC': 'maxtempC', 'Aberdeen,+SD_mintempC': 'mintempC',
       'Aberdeen,+SD_totalSnow_cm':'totalsnow_cm', 'Aberdeen,+SD_sunHour':'sunhour', 'Aberdeen,+SD_uvIndex':'uvIndex',
       'Aberdeen,+SD_moon_illumination':'moon_illumination',  'Aberdeen,+SD_moonrise':'moonrise',
       'Aberdeen,+SD_moonset':'moonset','Aberdeen,+SD_sunrise':'sunrise',
       'Aberdeen,+SD_sunset':'sunset', 'Aberdeen,+SD_DewPointC':'dewpointC',
       'Aberdeen,+SD_FeelsLikeC':'feelslikeC', 'Aberdeen,+SD_HeatIndexC':'heatindexC',
       'Aberdeen,+SD_WindChillC':'windchillC', 'Aberdeen,+SD_WindGustKmph':'windgustKmph',
       'Aberdeen,+SD_cloudcover':'cloudcover', 'Aberdeen,+SD_humidity':'humidity',
       'Aberdeen,+SD_precipMM':'precipMM', 'Aberdeen,+SD_pressure':'pressure', 'Aberdeen,+SD_tempC':'tempC',
       'Aberdeen,+SD_visibility':'visibility', 'Aberdeen,+SD_winddirDegree':'winddirectiondegree',
       'Aberdeen,+SD_windspeedKmph':'windspeedKmph', 'Aberdeen,+SD_location':'city' })

# %%
jan2019_weather = jan2019_weather.rename(columns={'Ogden,+UT_maxtempC': 'maxtempC', 'Ogden,+UT_mintempC': 'mintempC',
       'Ogden,+UT_totalSnow_cm':'totalsnow_cm', 'Ogden,+UT_sunHour':'sunhour', 'Ogden,+UT_uvIndex':'uvIndex',
       'Ogden,+UT_moon_illumination':'moon_illumination',  'Ogden,+UT_moonrise':'moonrise',
       'Ogden,+UT_moonset':'moonset','Ogden,+UT_sunrise':'sunrise',
       'Ogden,+UT_sunset':'sunset', 'Ogden,+UT_DewPointC':'dewpointC',
       'Ogden,+UT_FeelsLikeC':'feelslikeC', 'Ogden,+UT_HeatIndexC':'heatindexC',
       'Ogden,+UT_WindChillC':'windchillC', 'Ogden,+UT_WindGustKmph':'windgustKmph',
       'Ogden,+UT_cloudcover':'cloudcover', 'Ogden,+UT_humidity':'humidity',
       'Ogden,+UT_precipMM':'precipMM', 'Ogden,+UT_pressure':'pressure', 'Ogden,+UT_tempC':'tempC',
       'Ogden,+UT_visibility':'visibility', 'Ogden,+UT_winddirDegree':'winddirectiondegree',
       'Ogden,+UT_windspeedKmph':'windspeedKmph', 'Ogden,+UT_location':'city' })
len(jan2019_weather.city.unique())
# Out:
# 353

# %%
jan2020_weather = jan2020_weather.rename(columns={'Adak+Island,+AK_maxtempC': 'maxtempC', 'Adak+Island,+AK_mintempC': 'mintempC',
       'Adak+Island,+AK_totalSnow_cm':'totalsnow_cm', 'Adak+Island,+AK_sunHour':'sunhour', 'Adak+Island,+AK_uvIndex':'uvIndex',
       'Adak+Island,+AK_moon_illumination':'moon_illumination',  'Adak+Island,+AK_moonrise':'moonrise',
       'Adak+Island,+AK_moonset':'moonset','Adak+Island,+AK_sunrise':'sunrise',
       'Adak+Island,+AK_sunset':'sunset', 'Adak+Island,+AK_DewPointC':'dewpointC',
       'Adak+Island,+AK_FeelsLikeC':'feelslikeC', 'Adak+Island,+AK_HeatIndexC':'heatindexC',
       'Adak+Island,+AK_WindChillC':'windchillC', 'Adak+Island,+AK_WindGustKmph':'windgustKmph',
       'Adak+Island,+AK_cloudcover':'cloudcover', 'Adak+Island,+AK_humidity':'humidity',
       'Adak+Island,+AK_precipMM':'precipMM', 'Adak+Island,+AK_pressure':'pressure', 'Adak+Island,+AK_tempC':'tempC',
       'Adak+Island,+AK_visibility':'visibility', 'Adak+Island,+AK_winddirDegree':'winddirectiondegree',
       'Adak+Island,+AK_windspeedKmph':'windspeedKmph', 'Adak+Island,+AK_location':'city' })
len(jan2020_weather.city.unique())
# Out:
# 355

# %%
#rename cities
origin = data[['fl_date', 'origin_city_name']].rename(columns={'origin_city_name':'city'})
destin = data[['fl_date','dest_city_name']].rename(columns={'dest_city_name':'city'})

#concatenate to get unique values of city name
df_diff = pd.concat([origin,destin]).drop_duplicates()
citylist = df_diff.city.unique()
citylist
# Out:
# array(['Traverse City, MI', 'Omaha, NE', 'Minneapolis, MN',
#        'Indianapolis, IN', 'Fort Myers, FL', 'Nashville, TN',
#        'Orlando, FL', 'Boston, MA', 'New York, NY', 'Detroit, MI',
#        'Jacksonville/Camp Lejeune, NC', 'Mosinee, WI', 'St. Louis, MO',
#        'Appleton, WI', 'Atlanta, GA', 'Cincinnati, OH',
#        'Philadelphia, PA', 'Washington, DC', 'Asheville, NC',
#        'Pittsburgh, PA', 'Wilmington, NC', 'San Juan, PR', 'Newark, NJ',
#        'Fort Lauderdale, FL', 'Las Vegas, NV', 'Long Beach, CA',
#        'San Francisco, CA', 'San Diego, CA', 'Los Angeles, CA',
#        'Tampa, FL', 'Burlington, VT', 'Reno, NV', 'Savannah, GA',
#        'West Palm Beach/Palm Beach, FL', 'Albuquerque, NM',
#        'Salt Lake City, UT', 'New Orleans, LA', 'Buffalo, NY',
#        'Albany, NY', 'Denver, CO', 'Portland, ME', 'Chicago, IL',
#        'Syracuse, NY', 'Baltimore, MD', 'Raleigh/Durham, NC',
#        'Rochester, NY', 'Phoenix, AZ', 'Charleston, SC', 'Oakland, CA',
#        'Palm Springs, CA', 'Sacramento, CA', 'Sarasota/Bradenton, FL',
#        'Christiansted, VI', 'Burbank, CA', 'White Plains, NY',
#        'Seattle, WA', 'Cleveland, OH', 'Newburgh/Poughkeepsie, NY',
#        'San Jose, CA', 'Providence, RI', 'Jacksonville, FL',
#        'Daytona Beach, FL', 'Austin, TX', 'Hartford, CT', 'Aguadilla, PR',
#        'Richmond, VA', 'Ponce, PR', 'Dallas/Fort Worth, TX',
#        'Portland, OR', 'Worcester, MA', 'Honolulu, HI', 'Kahului, HI',
#        'Kona, HI', 'Lihue, HI', 'Hilo, HI', 'Atlantic City, NJ',
#        'Akron, OH', 'Plattsburgh, NY', 'New Bern/Morehead/Beaufort, NC',
#        'Newport News/Williamsburg, VA', 'Lexington, KY', 'Charlotte, NC',
#        'Tallahassee, FL', 'Charlottesville, VA', 'New Haven, CT',
#        'Knoxville, TN', 'Greensboro/High Point, NC', 'Memphis, TN',
#        'Toledo, OH', 'Myrtle Beach, SC', 'Fayetteville, NC',
#        'Birmingham, AL', 'Louisville, KY', 'Manchester, NH',
#        'Little Rock, AR', 'Greer, SC', 'Chattanooga, TN', 'Mobile, AL',
#        'Shreveport, LA', 'Dayton, OH', 'Madison, WI',
#        'Gulfport/Biloxi, MS', 'Jackson/Vicksburg, MS', 'Grand Rapids, MI',
#        'Columbus, OH', 'Houston, TX', 'Oklahoma City, OK',
#        'Kansas City, MO', 'Wichita, KS', 'Fayetteville, AR',
#        'Norfolk, VA', 'Rapid City, SD', 'Colorado Springs, CO',
#        'Boise, ID', 'Bozeman, MT', 'Milwaukee, WI', 'San Antonio, TX',
#        'Key West, FL', 'Des Moines, IA', 'Miami, FL', 'Ontario, CA',
#        'Santa Barbara, CA', 'Charlotte Amalie, VI', 'Tucson, AZ',
#        'El Paso, TX', 'Santa Ana, CA', 'Tulsa, OK', 'Valparaiso, FL',
#        'Gunnison, CO', 'Bangor, ME', 'Columbia, SC',
#        'Bristol/Johnson City/Kingsport, TN', 'Greenville, NC',
#        'Lynchburg, VA', 'Florence, SC', 'Ashland, WV', 'Augusta, GA',
#        'Erie, PA', 'Roanoke, VA', 'Islip, NY', 'Hilton Head, SC',
#        'Harrisburg, PA', 'Salisbury, MD', 'Ithaca/Cortland, NY',
#        'Eugene, OR', 'Spokane, WA', 'Pasco/Kennewick/Richland, WA',
#        'Missoula, MT', 'Bend/Redmond, OR', 'Kalamazoo, MI',
#        'Elmira/Corning, NY', 'Lafayette, LA', 'Montgomery, AL',
#        'Columbus, GA', 'Green Bay, WI', 'Valdosta, GA', 'Peoria, IL',
#        'Albany, GA', 'Bismarck/Mandan, ND', 'Brunswick, GA',
#        'Gainesville, FL', 'Alexandria, LA', 'Fargo, ND', 'Huntsville, AL',
#        'Lansing, MI', 'Harlingen/San Benito, TX', 'Baton Rouge, LA',
#        'Roswell, NM', 'Fort Smith, AR', 'Manhattan/Ft. Riley, KS',
#        'Santa Fe, NM', 'Midland/Odessa, TX', 'Pensacola, FL',
#        'Panama City, FL', 'Sioux Falls, SD', 'Springfield, MO',
#        'Corpus Christi, TX', 'Fort Wayne, IN', 'Charleston/Dunbar, WV',
#        'Lincoln, NE', 'Killeen, TX', 'Allentown/Bethlehem/Easton, PA',
#        'Moline, IL', 'Evansville, IN', 'Trenton, NJ', 'Pago Pago, TT',
#        'College Station/Bryan, TX', 'Amarillo, TX', 'San Angelo, TX',
#        'Rochester, MN', 'Sioux City, IA', 'Cedar Rapids/Iowa City, IA',
#        'Wichita Falls, TX', 'Champaign/Urbana, IL', 'Abilene, TX',
#        'Longview, TX', 'Lubbock, TX', 'Columbia, MO',
#        'Grand Junction, CO', 'Dubuque, IA', 'Niagara Falls, NY',
#        'Latrobe, PA', 'Dallas, TX', 'Flint, MI', 'Bloomington/Normal, IL',
#        'Durango, CO', 'Monterey, CA', 'Montrose/Delta, CO',
#        'San Luis Obispo, CA', 'Eagle, CO', 'Fresno, CA',
#        'State College, PA', 'Scranton/Wilkes-Barre, PA',
#        'Williamsport, PA', 'Jackson, WY', 'Anchorage, AK', 'Billings, MT',
#        'Guam, TT', 'Saipan, TT', 'Rota, TT', 'Williston, ND',
#        'Great Falls, MT', 'Dickinson, ND', 'Hayden, CO', 'Casper, WY',
#        'Kalispell, MT', 'Kodiak, AK', 'Bethel, AK', 'Deadhorse, AK',
#        'Barrow, AK', 'Fairbanks, AK', 'Juneau, AK', 'Ketchikan, AK',
#        'Sitka, AK', 'Nome, AK', 'Kotzebue, AK', 'Bellingham, WA',
#        'Minot, ND', 'Dothan, AL', 'Grand Forks, ND', 'Monroe, LA',
#        'South Bend, IN', 'Lake Charles, LA', 'Sanford, FL',
#        'St. Petersburg, FL', 'Belleville, IL', 'Hagerstown, MD',
#        'Rockford, IL', 'Owensboro, KY', 'Punta Gorda, FL', 'Concord, NC',
#        'Medford, OR', 'Grand Island, NE', 'Ogden, UT', 'Provo, UT',
#        'Youngstown/Warren, OH', 'Mission/McAllen/Edinburg, TX',
#        'Stockton, CA', 'Santa Maria, CA', 'Melbourne, FL', 'Hobbs, NM',
#        'Joplin, MO', 'Garden City, KS', 'Tyler, TX', 'Waterloo, IA',
#        'Springfield, IL', 'Marquette, MI', 'Stillwater, OK',
#        'Texarkana, AR', 'Waco, TX', 'Lawton/Fort Sill, OK',
#        'Beaumont/Port Arthur, TX', 'Aspen, CO', 'La Crosse, WI',
#        'Flagstaff, AZ', 'Santa Rosa, CA', 'Yuma, AZ', 'Meridian, MS',
#        'Hattiesburg/Laurel, MS', 'St. George, UT', 'Bullhead City, AZ',
#        'Cody, WY', 'Iron Mountain/Kingsfd, MI', 'Duluth, MN',
#        'Idaho Falls, ID', 'Sun Valley/Hailey/Ketchum, ID', 'Helena, MT',
#        'Twin Falls, ID', 'Saginaw/Bay City/Midland, MI', 'Columbus, MS',
#        'Eau Claire, WI', 'Clarksburg/Fairmont, WV', 'Rock Springs, WY',
#        'Pueblo, CO', 'Cape Girardeau, MO', 'Quincy, IL',
#        'Devils Lake, ND', 'Jamestown, ND', 'Laramie, WY',
#        'North Bend/Coos Bay, OR', 'Hays, KS', 'Gillette, WY',
#        'Arcata/Eureka, CA', 'Redding, CA', 'Bakersfield, CA',
#        'Mammoth Lakes, CA', 'Lewiston, ID', 'Pocatello, ID',
#        'Aberdeen, SD', 'Alpena, MI', 'Escanaba, MI', 'Pellston, MI',
#        'Bemidji, MN', 'Butte, MT', 'Cedar City, UT',
#        'Sault Ste. Marie, MI', 'Elko, NV', 'Hibbing, MN',
#        'Binghamton, NY', 'Rhinelander, WI', 'Brainerd, MN',
#        'International Falls, MN', 'Brownsville, TX', 'Laredo, TX',
#        'Hancock/Houghton, MI', 'Yakima, WA', 'Wenatchee, WA',
#        'Pullman, WA', 'Walla Walla, WA', 'Portsmouth, NH', 'Yakutat, AK',
#        'Cordova, AK', 'Wrangell, AK', 'Petersburg, AK', 'Muskegon, MI',
#        'Paducah, KY', 'Unalaska, AK', 'Watertown, NY', 'Ogdensburg, NY',
#        'St. Cloud, MN', 'Adak Island, AK', 'Scottsbluff, NE',
#        'Cheyenne, WY', 'Lewisburg, WV', 'Staunton, VA', 'Salina, KS',
#        'Kearney, NE', 'Vernal, UT', 'Moab, UT', 'Liberal, KS',
#        'Prescott, AZ', 'North Platte, NE', 'Hoolehua, HI', 'Kapalua, HI',
#        'Lanai, HI', 'Del Rio, TX', 'Presque Isle/Houlton, ME'],
#       dtype=object)

# %%
#rename cities
origin = data_test[['fl_date', 'origin_city_name']].rename(columns={'origin_city_name':'city'})
destin = data_test[['fl_date','dest_city_name']].rename(columns={'dest_city_name':'city'})

#concatenate to get unique values of city name
df_diff = pd.concat([origin,destin]).drop_duplicates()
citylist = df_diff.city.unique()
citylist
# Out:
# array(['Ontario, CA', 'Norfolk, VA', 'West Palm Beach/Palm Beach, FL',
#        'Portland, OR', 'Philadelphia, PA', 'Phoenix, AZ',
#        'Pittsburgh, PA', 'Pensacola, FL', 'Providence, RI',
#        'Portland, ME', 'Raleigh/Durham, NC', 'Richmond, VA', 'Reno, NV',
#        'Rochester, NY', 'Fort Myers, FL', 'San Diego, CA',
#        'San Antonio, TX', 'Louisville, KY', 'Seattle, WA',
#        'San Francisco, CA', 'San Jose, CA', 'San Juan, PR',
#        'Salt Lake City, UT', 'Sacramento, CA', 'Santa Ana, CA',
#        'St. Louis, MO', 'Tampa, FL', 'Tulsa, OK', 'Tucson, AZ',
#        'Harlingen/San Benito, TX', 'Duluth, MN', 'Chicago, IL',
#        'New York, NY', 'Greer, SC', 'Charlotte, NC', 'Houston, TX',
#        'Joplin, MO', 'Lexington, KY', 'Dallas/Fort Worth, TX',
#        'Miami, FL', 'New Orleans, LA', 'Cincinnati, OH',
#        'Champaign/Urbana, IL', 'State College, PA', 'Wilmington, NC',
#        'Manhattan/Ft. Riley, KS', 'Dayton, OH', 'Lawton/Fort Sill, OK',
#        'Springfield, MO', 'Springfield, IL', 'Shreveport, LA',
#        'Appleton, WI', 'Evansville, IN', 'Killeen, TX', 'Charleston, SC',
#        'Dubuque, IA', 'Allentown/Bethlehem/Easton, PA', 'Buffalo, NY',
#        'College Station/Bryan, TX', 'Gulfport/Biloxi, MS',
#        'Brownsville, TX', 'Tyler, TX', 'Fayetteville, AR',
#        'Montrose/Delta, CO', 'Peoria, IL', 'Little Rock, AR',
#        'Monroe, LA', 'Flint, MI', 'Waterloo, IA', 'Des Moines, IA',
#        'Texarkana, AR', 'Santa Rosa, CA', 'Cedar Rapids/Iowa City, IA',
#        'Sioux Falls, SD', 'Tallahassee, FL', 'La Crosse, WI',
#        'Moline, IL', 'Fort Smith, AR', 'Key West, FL', 'Atlanta, GA',
#        'Bloomington/Normal, IL', 'Columbia, SC', 'Grand Junction, CO',
#        'Cleveland, OH', 'Colorado Springs, CO', 'Corpus Christi, TX',
#        'Detroit, MI', 'Fargo, ND', 'Fort Wayne, IN', 'Garden City, KS',
#        'Spokane, WA', 'Green Bay, WI', 'Grand Island, NE',
#        'Harrisburg, PA', 'Grand Rapids, MI', 'San Angelo, TX',
#        'Wichita Falls, TX', 'Abilene, TX', 'Laredo, TX',
#        'Greensboro/High Point, NC', 'Bozeman, MT', 'Columbus, OH',
#        'Huntsville, AL', 'Wichita, KS', 'Jacksonville, FL', 'Lubbock, TX',
#        'Lake Charles, LA', 'Kansas City, MO', 'Memphis, TN',
#        'Mission/McAllen/Edinburg, TX', 'Madison, WI', 'Missoula, MT',
#        'Omaha, NE', 'Oklahoma City, OK', 'Sarasota/Bradenton, FL',
#        'Santa Barbara, CA', 'Gunnison, CO', 'Washington, DC',
#        'Albuquerque, NM', 'Austin, TX', 'Lafayette, LA', 'Boston, MA',
#        'Nashville, TN', 'Fort Lauderdale, FL', 'Burlington, VT',
#        'Savannah, GA', 'Midland/Odessa, TX', 'Mobile, AL',
#        'Baton Rouge, LA', 'Milwaukee, WI', 'El Paso, TX', 'Akron, OH',
#        'Hartford, CT', 'Indianapolis, IN', 'Panama City, FL',
#        'Honolulu, HI', 'Kahului, HI', 'Oakland, CA', 'Los Angeles, CA',
#        'Kona, HI', 'Lihue, HI', 'Long Beach, CA', 'Hilo, HI',
#        'Hoolehua, HI', 'Lanai, HI', 'Kapalua, HI',
#        'Scranton/Wilkes-Barre, PA', 'Lynchburg, VA', 'Asheville, NC',
#        'Charlottesville, VA', 'Birmingham, AL', 'Knoxville, TN',
#        'Manchester, NH', 'Chattanooga, TN', 'Bangor, ME', 'Augusta, GA',
#        'White Plains, NY', 'Valparaiso, FL',
#        'Jacksonville/Camp Lejeune, NC', 'South Bend, IN', 'Syracuse, NY',
#        'Daytona Beach, FL', 'Newport News/Williamsburg, VA',
#        'Gainesville, FL', 'Kalispell, MT', 'Bend/Redmond, OR',
#        'Eugene, OR', 'Boise, ID', 'Great Falls, MT', 'Medford, OR',
#        'Pasco/Kennewick/Richland, WA', 'Palm Springs, CA',
#        'Sun Valley/Hailey/Ketchum, ID', 'Billings, MT', 'Dallas, TX',
#        'Minneapolis, MN', 'Bellingham, WA', 'Hayden, CO', 'Las Vegas, NV',
#        'Everett, WA', 'Newark, NJ', 'Denver, CO', 'Orlando, FL',
#        'Baltimore, MD', 'Eagle, CO', 'Fresno, CA', 'Jackson, WY',
#        'Charlotte Amalie, VI', 'Myrtle Beach, SC', 'Albany, NY',
#        'Aguadilla, PR', 'Atlantic City, NJ', 'Latrobe, PA', 'Yuma, AZ',
#        'Flagstaff, AZ', 'Columbia, MO', 'San Luis Obispo, CA',
#        'Aspen, CO', 'Santa Fe, NM', 'Roswell, NM', 'Montgomery, AL',
#        'Hattiesburg/Laurel, MS', 'Cheyenne, WY', 'St. George, UT',
#        'Meridian, MS', 'Charleston/Dunbar, WV', 'Rapid City, SD',
#        'Traverse City, MI', 'Burbank, CA', 'Monterey, CA',
#        'Brunswick, GA', 'Bismarck/Mandan, ND', 'Grand Forks, ND',
#        'Albany, GA', 'Twin Falls, ID', 'Minot, ND', 'Roanoke, VA',
#        'Kalamazoo, MI', 'Lansing, MI', 'Elmira/Corning, NY',
#        'Idaho Falls, ID', 'Valdosta, GA', 'Erie, PA',
#        'Bristol/Johnson City/Kingsport, TN', 'Lincoln, NE',
#        'Columbus, MS', 'Williston, ND', 'Helena, MT', 'Dothan, AL',
#        'Fayetteville, NC', 'Rochester, MN', 'Elko, NV',
#        'International Falls, MN', 'Pocatello, ID', 'Ithaca/Cortland, NY',
#        'Binghamton, NY', 'Sault Ste. Marie, MI', 'Brainerd, MN',
#        'Casper, WY', 'Cedar City, UT', 'Hibbing, MN', 'Marquette, MI',
#        'Aberdeen, SD', 'Pellston, MI', 'Lewiston, ID', 'Alpena, MI',
#        'Escanaba, MI', 'Iron Mountain/Kingsfd, MI', 'Butte, MT',
#        'Bemidji, MN', 'Rhinelander, WI', 'Newburgh/Poughkeepsie, NY',
#        'Devils Lake, ND', 'Jamestown, ND', 'Moab, UT', 'Muskegon, MI',
#        'Hays, KS', 'Salina, KS', 'Gillette, WY',
#        'Clarksburg/Fairmont, WV', 'Saginaw/Bay City/Midland, MI',
#        'Rock Springs, WY', 'Ogdensburg, NY', 'Liberal, KS', 'Pueblo, CO',
#        'Kearney, NE', 'Eau Claire, WI', 'Quincy, IL', 'Plattsburgh, NY',
#        'Vernal, UT', 'North Platte, NE', 'Lewisburg, WV', 'Staunton, VA',
#        'Scottsbluff, NE', 'Cape Girardeau, MO', 'Watertown, SD',
#        'Hancock/Houghton, MI', 'Stockton, CA', 'Laramie, WY',
#        'Pierre, SD', 'Paducah, KY', 'Prescott, AZ', 'Cody, WY',
#        'Arcata/Eureka, CA', 'Bakersfield, CA', 'Mosinee, WI', 'Hobbs, NM',
#        'Mammoth Lakes, CA', 'Redding, CA', 'North Bend/Coos Bay, OR',
#        'Jackson/Vicksburg, MS', 'Durango, CO', 'Anchorage, AK',
#        'Hilton Head, SC', 'Columbus, GA', 'Alexandria, LA',
#        'Amarillo, TX', 'Melbourne, FL', 'New Bern/Morehead/Beaufort, NC',
#        'Toledo, OH', 'Christiansted, VI', 'Niagara Falls, NY',
#        'Fairbanks, AK', 'Islip, NY', 'Stillwater, OK', 'Sioux City, IA',
#        'Beaumont/Port Arthur, TX', 'Waco, TX', 'Longview, TX',
#        'Worcester, MA', 'Yakima, WA', 'Walla Walla, WA', 'Pullman, WA',
#        'Wenatchee, WA', 'Watertown, NY', 'Florence, SC', 'Salisbury, MD',
#        'Ashland, WV', 'Williamsport, PA', 'Trenton, NJ', 'New Haven, CT',
#        'Punta Gorda, FL', 'Rockford, IL', 'Provo, UT',
#        'St. Petersburg, FL', 'Sanford, FL', 'Concord, NC',
#        'Santa Maria, CA', 'Belleville, IL', 'Del Rio, TX', 'Ponce, PR',
#        'Kodiak, AK', 'Bethel, AK', 'Barrow, AK', 'Deadhorse, AK',
#        'Ketchikan, AK', 'Juneau, AK', 'Sitka, AK', 'Petersburg, AK',
#        'Wrangell, AK', 'Nome, AK', 'Kotzebue, AK', 'Adak Island, AK',
#        'Greenville, NC', 'Guam, TT', 'Saipan, TT',
#        'Presque Isle/Houlton, ME', 'Dickinson, ND', 'Hagerstown, MD',
#        'Cordova, AK', 'Yakutat, AK', 'Pago Pago, TT', 'Portsmouth, NH',
#        'Owensboro, KY', 'Ogden, UT', 'St. Cloud, MN', 'Sheridan, WY',
#        'Riverton/Lander, WY'], dtype=object)

# %%
#remove '+' and replace with whitespace

jan2018_weather['city'] = jan2018_weather['city'].str.replace('+', ' ')

jan2019_weather['city'] = jan2019_weather['city'].str.replace('+', ' ')
# Out:
# C:\Users\bevli\AppData\Local\Temp/ipykernel_2832/4000334870.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   jan2018_weather['city'] = jan2018_weather['city'].str.replace('+', ' ')
# C:\Users\bevli\AppData\Local\Temp/ipykernel_2832/4000334870.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   jan2019_weather['city'] = jan2019_weather['city'].str.replace('+', ' ')

# %%
#remove '+' and replace with whitespace

jan2020_weather['city'] = jan2020_weather['city'].str.replace('+', ' ')
# Out:
# C:\Users\bevli\AppData\Local\Temp/ipykernel_13564/279540675.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   jan2020_weather['city'] = jan2020_weather['city'].str.replace('+', ' ')

# %%
def originalcitynames(df):
    for i in citylist:
        df.city = df.city.apply(lambda x: i if i[:7] in x and i[-3:] in x else x)

# %%
originalcitynames(jan2018_weather)

# %%
len(jan2018_weather.city.unique())
# Out:
# 343

# %%
originalcitynames(jan2019_weather)

# %%
len(jan2019_weather.city.unique())
# Out:
# 353

# %%
originalcitynames(jan2020_weather)

# %%
len(jan2020_weather.city.unique())
# Out:
# 355

# %%
#to get original city name with county
citylist_original = []
for i in citylist:
    if '/' in i:
        citylist_original.append(i)
citylist_original

def originalcitynames_final(df):
    for i in citylist_original:
        df.city = df.city.apply(lambda x: i if i[:7] in x and i[-3:] in x else x)

# %%
originalcitynames_final(jan2018_weather)
originalcitynames_final(jan2019_weather)

# %%
originalcitynames_final(jan2020_weather)

# %%
len(jan2020_weather.city.unique())
# Out:
# 355

# %%
jan2020_weather.columns
# Out:
# Index(['date_time', 'maxtempC', 'mintempC', 'totalsnow_cm', 'sunhour',
#        'uvIndex', 'moon_illumination', 'moonrise', 'moonset', 'sunrise',
#        'sunset', 'dewpointC', 'feelslikeC', 'heatindexC', 'windchillC',
#        'windgustKmph', 'cloudcover', 'humidity', 'precipMM', 'pressure',
#        'tempC', 'visibility', 'winddirectiondegree', 'windspeedKmph', 'city'],
#       dtype='object')

# %%
jan2018_weather.columns
# Out:
# Index(['date_time', 'maxtempC', 'mintempC', 'totalsnow_cm', 'sunhour',
#        'uvIndex', 'moon_illumination', 'moonrise', 'moonset', 'sunrise',
#        'sunset', 'dewpointC', 'feelslikeC', 'heatindexC', 'windchillC',
#        'windgustKmph', 'cloudcover', 'humidity', 'precipMM', 'pressure',
#        'tempC', 'visibility', 'winddirectiondegree', 'windspeedKmph', 'city'],
#       dtype='object')

# %% [markdown]
# ### Merge Tables

# %%
#make copies of data for origin and destination cities

origin_jan_2018 = jan2018_weather.copy()
origin_jan_2018 = origin_jan_2018.rename(columns={ 'maxtempC':'OriginmaxtempC', 'mintempC':'OriginmintempC', 
                                                  'totalsnow_cm':'Origintotalsnow_cm', 'sunhour':'Originsunhour',
       'uvIndex':'OriginuvIndex', 'moon_illumination':'Originmoon_illumination', 'moonrise':'Originmoonrise', 
                                                  'moonset':'Originmoonset', 'sunrise':'Originsunrise',
       'sunset':'Originsunset', 'dewpointC':'OrigindewpointC', 'feelslikeC':'OriginfeelslikeC', 'heatindexC':'OriginheatindexC',
                                                  'windchillC':'OriginwindchillC',
       'windgustKmph':'OriginwindgustKmph', 'cloudcover':'Origincloudcover', 'humidity':'Originhumidity', 
                                                  'precipMM':'OriginprecipMM', 'pressure':'Originpressure',
       'tempC':'OrigintempC', 'visibility':'Originvisibility', 'winddirectiondegree':'Originwinddirectiondegree', 
                                                  'windspeedKmph':'OriginwindspeedKmph' })


destin_jan_2018 = jan2018_weather.copy()
destin_jan_2018 = destin_jan_2018.rename(columns={ 'maxtempC':'DestinmaxtempC', 'mintempC':'DestinmintempC', 
                                                  'totalsnow_cm':'Destintotalsnow_cm', 'sunhour':'Destinsunhour',
       'uvIndex':'DestinuvIndex', 'moon_illumination':'Destinmoon_illumination', 'moonrise':'Destinmoonrise', 
                                                  'moonset':'Destinmoonset', 'sunrise':'Destinsunrise',
       'sunset':'Destinsunset', 'dewpointC':'DestindewpointC', 'feelslikeC':'DestinfeelslikeC', 'heatindexC':'DestinheatindexC',
                                                  'windchillC':'DestinwindchillC',
       'windgustKmph':'DestinwindgustKmph', 'cloudcover':'Destincloudcover', 'humidity':'Destinhumidity', 
                                                  'precipMM':'DestinprecipMM', 'pressure':'Destinpressure',
       'tempC':'DestintempC', 'visibility':'Destinvisibility', 'winddirectiondegree':'Destinwinddirectiondegree', 
                                                  'windspeedKmph':'DestinwindspeedKmph' })


origin_jan_2019 = jan2019_weather.copy()
origin_jan_2019 = origin_jan_2019.rename(columns={ 'maxtempC':'OriginmaxtempC', 'mintempC':'OriginmintempC', 
                                                  'totalsnow_cm':'Origintotalsnow_cm', 'sunhour':'Originsunhour',
       'uvIndex':'OriginuvIndex', 'moon_illumination':'Originmoon_illumination', 'moonrise':'Originmoonrise', 
                                                  'moonset':'Originmoonset', 'sunrise':'Originsunrise',
       'sunset':'Originsunset', 'dewpointC':'OrigindewpointC', 'feelslikeC':'OriginfeelslikeC', 'heatindexC':'OriginheatindexC',
                                                  'windchillC':'OriginwindchillC',
       'windgustKmph':'OriginwindgustKmph', 'cloudcover':'Origincloudcover', 'humidity':'Originhumidity', 
                                                  'precipMM':'OriginprecipMM', 'pressure':'Originpressure',
       'tempC':'OrigintempC', 'visibility':'Originvisibility', 'winddirectiondegree':'Originwinddirectiondegree', 
                                                  'windspeedKmph':'OriginwindspeedKmph' })

destin_jan_2019 = jan2019_weather.copy()
destin_jan_2019 = destin_jan_2019.rename(columns={ 'maxtempC':'DestinmaxtempC', 'mintempC':'DestinmintempC', 
                                                  'totalsnow_cm':'Destintotalsnow_cm', 'sunhour':'Destinsunhour',
       'uvIndex':'DestinuvIndex', 'moon_illumination':'Destinmoon_illumination', 'moonrise':'Destinmoonrise', 
                                                  'moonset':'Destinmoonset', 'sunrise':'Destinsunrise',
       'sunset':'Destinsunset', 'dewpointC':'DestindewpointC', 'feelslikeC':'DestinfeelslikeC', 'heatindexC':'DestinheatindexC',
                                                  'windchillC':'DestinwindchillC',
       'windgustKmph':'DestinwindgustKmph', 'cloudcover':'Destincloudcover', 'humidity':'Destinhumidity', 
                                                  'precipMM':'DestinprecipMM', 'pressure':'Destinpressure',
       'tempC':'DestintempC', 'visibility':'Destinvisibility', 'winddirectiondegree':'Destinwinddirectiondegree', 
                                                  'windspeedKmph':'DestinwindspeedKmph' })

# %%
origin_jan_2020 = jan2020_weather.copy()
origin_jan_2020 = origin_jan_2020.rename(columns={ 'maxtempC':'OriginmaxtempC', 'mintempC':'OriginmintempC', 
                                                  'totalsnow_cm':'Origintotalsnow_cm', 'sunhour':'Originsunhour',
       'uvIndex':'OriginuvIndex', 'moon_illumination':'Originmoon_illumination', 'moonrise':'Originmoonrise', 
                                                  'moonset':'Originmoonset', 'sunrise':'Originsunrise',
       'sunset':'Originsunset', 'dewpointC':'OrigindewpointC', 'feelslikeC':'OriginfeelslikeC', 'heatindexC':'OriginheatindexC',
                                                  'windchillC':'OriginwindchillC',
       'windgustKmph':'OriginwindgustKmph', 'cloudcover':'Origincloudcover', 'humidity':'Originhumidity', 
                                                  'precipMM':'OriginprecipMM', 'pressure':'Originpressure',
       'tempC':'OrigintempC', 'visibility':'Originvisibility', 'winddirectiondegree':'Originwinddirectiondegree', 
                                                  'windspeedKmph':'OriginwindspeedKmph' })

destin_jan_2020 = jan2020_weather.copy()
destin_jan_2020 = destin_jan_2020.rename(columns={ 'maxtempC':'DestinmaxtempC', 'mintempC':'DestinmintempC', 
                                                  'totalsnow_cm':'Destintotalsnow_cm', 'sunhour':'Destinsunhour',
       'uvIndex':'DestinuvIndex', 'moon_illumination':'Destinmoon_illumination', 'moonrise':'Destinmoonrise', 
                                                  'moonset':'Destinmoonset', 'sunrise':'Destinsunrise',
       'sunset':'Destinsunset', 'dewpointC':'DestindewpointC', 'feelslikeC':'DestinfeelslikeC', 'heatindexC':'DestinheatindexC',
                                                  'windchillC':'DestinwindchillC',
       'windgustKmph':'DestinwindgustKmph', 'cloudcover':'Destincloudcover', 'humidity':'Destinhumidity', 
                                                  'precipMM':'DestinprecipMM', 'pressure':'Destinpressure',
       'tempC':'DestintempC', 'visibility':'Destinvisibility', 'winddirectiondegree':'Destinwinddirectiondegree', 
                                                  'windspeedKmph':'DestinwindspeedKmph' })

# %%
#drop unnecessary features
origin_columns_drop = ['OriginuvIndex','Originmoon_illumination','Originmoonrise','Originmoonset','Originsunrise',
                    'Originsunset', 'OrigindewpointC','Originpressure','Originwinddirectiondegree']

destin_columns_drop = ['DestinuvIndex','Destinmoon_illumination','Destinmoonrise','Destinmoonset','Destinsunrise',
                    'Destinsunset', 'DestindewpointC','Destinpressure','Destinwinddirectiondegree' ]

origin_jan_2018.drop(columns = origin_columns_drop, inplace = True)

origin_jan_2019.drop(columns = origin_columns_drop, inplace = True)

destin_jan_2018.drop(columns = destin_columns_drop, inplace = True)

destin_jan_2019.drop(columns = destin_columns_drop, inplace = True)

# %%
#drop unnecessary features
origin_columns_drop = ['OriginuvIndex','Originmoon_illumination','Originmoonrise','Originmoonset','Originsunrise',
                    'Originsunset', 'OrigindewpointC','Originpressure','Originwinddirectiondegree']

destin_columns_drop = ['DestinuvIndex','Destinmoon_illumination','Destinmoonrise','Destinmoonset','Destinsunrise',
                    'Destinsunset', 'DestindewpointC','Destinpressure','Destinwinddirectiondegree']

origin_jan_2020.drop(columns = origin_columns_drop, inplace = True)

destin_jan_2020.drop(columns = destin_columns_drop, inplace = True)

# %%
#merging origin and destination

origin_jan_weather = pd.concat([origin_jan_2018,origin_jan_2019])
origin_jan_weather = origin_jan_weather.rename(columns={ 'date_time':'fl_date', 'city':'origin_city_name'})
origin_jan_weather['fl_date'] = pd.to_datetime(origin_jan_weather['fl_date'])

destin_jan_weather = pd.concat([destin_jan_2018,destin_jan_2019])
destin_jan_weather = destin_jan_weather.rename(columns={ 'date_time':'fl_date', 'city':'dest_city_name'})
destin_jan_weather['fl_date'] = pd.to_datetime(destin_jan_weather['fl_date'])

data['fl_date'] = pd.to_datetime(data['fl_date'])

# %%
#change 
origin_jan_2020 = origin_jan_2020.rename(columns={ 'date_time':'fl_date', 'city':'origin_city_name'})
origin_jan_2020['fl_date'] = pd.to_datetime(origin_jan_2020['fl_date'])


destin_jan_2020 = destin_jan_2020.rename(columns={ 'date_time':'fl_date', 'city':'dest_city_name'})
destin_jan_2020['fl_date'] = pd.to_datetime(destin_jan_2020['fl_date'])

# %%
# merging origin_jan_weather and data
df_merged = pd.merge(data, origin_jan_weather, left_on=['fl_date','origin_city_name'],right_on=['fl_date','origin_city_name'], how = 'inner')

# %%
# merging destin_jan_weather and data
df_merged_final = pd.merge(df_merged, destin_jan_weather, left_on=['fl_date','dest_city_name'],right_on=['fl_date','dest_city_name'], how = 'inner')

# %%
data_test['fl_date'] = pd.to_datetime(data_test['fl_date'])

# %%
# merging origin_jan_weather and data_test
df_merged = pd.merge(data_test, origin_jan_2020, left_on=['fl_date','origin_city_name'],right_on=['fl_date','origin_city_name'], how = 'inner')

# %%
# merging destin_jan_weather and data_test
df_merged_final = pd.merge(df_merged, destin_jan_2020, left_on=['fl_date','dest_city_name'],right_on=['fl_date','dest_city_name'], how = 'inner')

# %%
df_merged_final
# Out:
#        Unnamed: 0    fl_date mkt_unique_carrier branded_code_share  \
# 0              14 2020-01-01                 WN                 WN
# 1              15 2020-01-01                 WN                 WN
# 2              16 2020-01-01                 WN                 WN
# 3              17 2020-01-01                 WN                 WN
# 4              21 2020-01-01                 WN                 WN
# ...           ...        ...                ...                ...
# 17765       15971 2020-01-01                 AS                 AS
# 17766       15956 2020-01-01                 AS                 AS
# 17767       15963 2020-01-01                 AS                 AS
# 17768       15958 2020-01-01                 AS                 AS
# 17769       18856 2020-01-01                 UA                 UA
#
#       mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 0              WN                3719                WN   N941WN
# 1              WN                4863                WN   N496WN
# 2              WN                4924                WN   N7732A
# 3              WN                5321                WN   N7863A
# 4              WN                4887                WN   N246LV
# ...           ...                 ...               ...      ...
# 17765          AS                  70                AS   N644AS
# 17766          AS                  64                AS   N622AS
# 17767          AS                  65                AS   N607AS
# 17768          AS                  64                AS   N622AS
# 17769          UA                 174                UA   N34282
#
#        op_carrier_fl_num  origin_airport_id  ... DestinfeelslikeC  \
# 0                   3719              13931  ...                1
# 1                   4863              13931  ...                1
# 2                   4924              13931  ...                1
# 3                   5321              13931  ...                1
# 4                   4887              14027  ...                1
# ...                  ...                ...  ...              ...
# 17765                 70              12523  ...               -3
# 17766                 64              12523  ...               -3
# 17767                 65              15841  ...               -3
# 17768                 64              14256  ...               -3
# 17769                174              12016  ...               31
#
#       DestinheatindexC  DestinwindchillC DestinwindgustKmph Destincloudcover  \
# 0                    5                 1                 23               14
# 1                    5                 1                 23               14
# 2                    5                 1                 23               14
# 3                    5                 1                 23               14
# 4                    5                 1                 23               14
# ...                ...               ...                ...              ...
# 17765                1                -3                 23               94
# 17766                1                -3                 16               96
# 17767                1                -3                 16               96
# 17768                1                -3                 16               96
# 17769               31                27                 51               81
#
#        Destinhumidity  DestinprecipMM DestintempC  Destinvisibility  \
# 0                  52             0.0           7                10
# 1                  52             0.0           7                10
# 2                  52             0.0           7                10
# 3                  52             0.0           7                10
# 4                  52             0.0           7                10
# ...               ...             ...         ...               ...
# 17765              84            48.3           2                 5
# 17766              88            21.0           3                 5
# 17767              88            21.0           3                 5
# 17768              88            21.0           3                 5
# 17769              81            11.7          28                 9
#
#        DestinwindspeedKmph
# 0                       17
# 1                       17
# 2                       17
# 3                       17
# 4                       17
# ...                    ...
# 17765                   18
# 17766                   12
# 17767                   12
# 17768                   12
# 17769                   34
#
# [17770 rows x 49 columns]

# %%
df_merged_final.to_csv('df_merged_final_test.csv')

# %%
df_merged_final.columns
# Out:
# Index(['Unnamed: 0', 'fl_date', 'mkt_unique_carrier', 'branded_code_share',
#        'mkt_carrier', 'mkt_carrier_fl_num', 'op_unique_carrier', 'tail_num',
#        'op_carrier_fl_num', 'origin_airport_id', 'origin', 'origin_city_name',
#        'dest_airport_id', 'dest', 'dest_city_name', 'crs_dep_time',
#        'crs_arr_time', 'dup', 'crs_elapsed_time', 'flights', 'distance',
#        'OriginmaxtempC', 'OriginmintempC', 'Origintotalsnow_cm',
#        'Originsunhour', 'OriginfeelslikeC', 'OriginheatindexC',
#        'OriginwindchillC', 'OriginwindgustKmph', 'Origincloudcover',
#        'Originhumidity', 'OriginprecipMM', 'OrigintempC', 'Originvisibility',
#        'OriginwindspeedKmph', 'DestinmaxtempC', 'DestinmintempC',
#        'Destintotalsnow_cm', 'Destinsunhour', 'DestinfeelslikeC',
#        'DestinheatindexC', 'DestinwindchillC', 'DestinwindgustKmph',
#        'Destincloudcover', 'Destinhumidity', 'DestinprecipMM', 'DestintempC',
#        'Destinvisibility', 'DestinwindspeedKmph'],
#       dtype='object')

# %%
# encode the weather data at origin
def newlabel_origin(df):
    
    if df['Origincloudcover']<40 and df['OriginprecipMM'] == 0:
        return "clear"
    if df['Origincloudcover']>=40 and df['OriginprecipMM'] == 0:
        return "cloudy"
    if 0<df['OriginprecipMM']<=10:
        return "lightrain"
    if 10<df['OriginprecipMM']<=25:
        return "heavyrain"
    if df['OriginprecipMM']>25:
        return "storm"

df_merged_final['Weather_origin']=df_merged_final.apply(newlabel_origin, axis=1)

# encode the weather data at destination
def newlabel_destin(df):
    
    if df['Destincloudcover']<40 and df['DestinprecipMM'] == 0:
        return "clear"
    if df['Destincloudcover']>=40 and df['DestinprecipMM'] == 0:
        return "cloudy"
    if 0<df['DestinprecipMM']<=10:
        return "lightrain"
    if 10<df['DestinprecipMM']<=25:
        return "heavyrain"
    if df['DestinprecipMM']>25:
        return "storm"

df_merged_final['Weather_destin']=df_merged_final.apply(newlabel_destin, axis=1)

# %%
# encode the visibility 
def visibility_origin(df):
    
    if df['Originvisibility']<7:
        return "lowvisibility"
    if 7<=df['Originvisibility']<9:
        return "mediumvisbility"
    if df['Originvisibility']>=9:
        return "highvisibility"
    

df_merged_final['Visibility_origin']=df_merged_final.apply(visibility_origin, axis=1)

def visibility_destin(df):
    if df['Destinvisibility']<7:
        return "lowvisibility"
    if 7<=df['Destinvisibility']<9:
        return "mediumvisbility"
    if df['Destinvisibility']>=9:
        return "highvisibility"
    
df_merged_final['Visibility_destin']=df_merged_final.apply(visibility_destin, axis=1)

# %%
#encode the wind speed
def windspeed_origin(df):
    
    if df['OriginwindgustKmph']<45:
        return "lowwindspeed"
    if df['OriginwindgustKmph']>=45:
        return "highwindspeed"

df_merged_final['windspeed_origin']=df_merged_final.apply(windspeed_origin, axis=1)


def windspeed_destin(df):
    
    if df['DestinwindgustKmph']<45:
        return "lowwindspeed"
    if df['DestinwindgustKmph']>=45:
        return "highwindspeed"
    
df_merged_final['windspeed_destin']=df_merged_final.apply(windspeed_destin, axis=1)

# %%
df_merged_final[df_merged_final.isnull().any(axis=1)]
# Out:
#        Unnamed: 0    fl_date mkt_unique_carrier branded_code_share  \
# 1579         5099 2020-01-01                 UA                 UA
# 3903         4009 2020-01-01                 DL       DL_CODESHARE
# 6599        19194 2020-01-01                 UA       UA_CODESHARE
# 6707        14269 2020-01-01                 F9                 F9
# 6764        19101 2020-01-01                 UA       UA_CODESHARE
# 6825        18632 2020-01-01                 UA                 UA
# 11422       14268 2020-01-01                 F9                 F9
# 11477        3480 2020-01-01                 DL       DL_CODESHARE
# 11479        3680 2020-01-01                 DL       DL_CODESHARE
# 12556        1735 2020-01-01                 HA       HA_CODESHARE
# 12557        1737 2020-01-01                 HA       HA_CODESHARE
# 12558        1741 2020-01-01                 HA       HA_CODESHARE
# 12559        1751 2020-01-01                 HA       HA_CODESHARE
# 12810       14267 2020-01-01                 F9                 F9
# 16994       19187 2020-01-01                 UA       UA_CODESHARE
# 17052        5517 2020-01-01                 UA                 UA
# 17691        1734 2020-01-01                 HA       HA_CODESHARE
# 17692        1736 2020-01-01                 HA       HA_CODESHARE
# 17693        1740 2020-01-01                 HA       HA_CODESHARE
# 17694        1750 2020-01-01                 HA       HA_CODESHARE
#
#       mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 1579           UA                2238                UA      NaN
# 3903           DL                4274                OO      NaN
# 6599           UA                4654                AX      NaN
# 6707           F9                 406                F9      NaN
# 6764           UA                4744                AX      NaN
# 6825           UA                 406                UA      NaN
# 11422          F9                1903                F9      NaN
# 11477          DL                3545                OO      NaN
# 11479          DL                3784                OO      NaN
# 12556          HA                 629                EM      NaN
# 12557          HA                 639                EM      NaN
# 12558          HA                 649                EM      NaN
# 12559          HA                 679                EM      NaN
# 12810          F9                1902                F9      NaN
# 16994          UA                4661                AX      NaN
# 17052          UA                1771                UA      NaN
# 17691          HA                 628                EM      NaN
# 17692          HA                 638                EM      NaN
# 17693          HA                 648                EM      NaN
# 17694          HA                 678                EM      NaN
#
#        op_carrier_fl_num  origin_airport_id  ... DestinprecipMM DestintempC  \
# 1579                2238              13487  ...            0.0           2
# 3903                4274              11013  ...            0.3           1
# 6599                4654              12012  ...            0.1           5
# 6707                 406              12892  ...            0.1           5
# 6764                4744              12094  ...            0.1           5
# 6825                 406              12441  ...            0.1           5
# 11422               1903              10423  ...            8.9           0
# 11477               3545              15041  ...            8.9           0
# 11479               3784              15041  ...            8.9           0
# 12556                629              12492  ...            1.0          25
# 12557                639              12492  ...            1.0          25
# 12558                649              12492  ...            1.0          25
# 12559                679              12492  ...            1.0          25
# 12810               1902              14869  ...           10.1          11
# 16994               4661              11292  ...           15.4          -6
# 17052               1771              11292  ...           28.3          -5
# 17691                628              12173  ...            1.0          24
# 17692                638              12173  ...            1.0          24
# 17693                648              12173  ...            1.0          24
# 17694                678              12173  ...            1.0          24
#
#        Destinvisibility DestinwindspeedKmph Weather_origin  Weather_destin  \
# 1579                 10                  19          clear           clear
# 3903                 10                  18      lightrain       lightrain
# 6599                 10                   8      lightrain       lightrain
# 6707                 10                   8          clear       lightrain
# 6764                 10                   8      heavyrain       lightrain
# 6825                 10                   8          storm       lightrain
# 11422                 4                  13      heavyrain       lightrain
# 11477                 4                  13      lightrain       lightrain
# 11479                 4                  13      lightrain       lightrain
# 12556                10                  10      lightrain       lightrain
# 12557                10                  10      lightrain       lightrain
# 12558                10                  10      lightrain       lightrain
# 12559                10                  10      lightrain       lightrain
# 12810                 9                   8      lightrain       heavyrain
# 16994                 5                   6      lightrain       heavyrain
# 17052                 2                   9      lightrain           storm
# 17691                10                  19      lightrain       lightrain
# 17692                10                  19      lightrain       lightrain
# 17693                10                  19      lightrain       lightrain
# 17694                10                  19      lightrain       lightrain
#
#        Visibility_origin Visibility_destin  windspeed_origin  windspeed_destin
# 1579      highvisibility    highvisibility      lowwindspeed      lowwindspeed
# 3903       lowvisibility    highvisibility      lowwindspeed      lowwindspeed
# 6599     mediumvisbility    highvisibility      lowwindspeed      lowwindspeed
# 6707      highvisibility    highvisibility      lowwindspeed      lowwindspeed
# 6764       lowvisibility    highvisibility      lowwindspeed      lowwindspeed
# 6825       lowvisibility    highvisibility      lowwindspeed      lowwindspeed
# 11422     highvisibility     lowvisibility      lowwindspeed      lowwindspeed
# 11477      lowvisibility     lowvisibility      lowwindspeed      lowwindspeed
# 11479      lowvisibility     lowvisibility      lowwindspeed      lowwindspeed
# 12556     highvisibility    highvisibility      lowwindspeed      lowwindspeed
# 12557     highvisibility    highvisibility      lowwindspeed      lowwindspeed
# 12558     highvisibility    highvisibility      lowwindspeed      lowwindspeed
# 12559     highvisibility    highvisibility      lowwindspeed      lowwindspeed
# 12810      lowvisibility    highvisibility      lowwindspeed      lowwindspeed
# 16994     highvisibility     lowvisibility      lowwindspeed      lowwindspeed
# 17052     highvisibility     lowvisibility      lowwindspeed      lowwindspeed
# 17691     highvisibility    highvisibility      lowwindspeed      lowwindspeed
# 17692     highvisibility    highvisibility      lowwindspeed      lowwindspeed
# 17693     highvisibility    highvisibility      lowwindspeed      lowwindspeed
# 17694     highvisibility    highvisibility      lowwindspeed      lowwindspeed
#
# [20 rows x 55 columns]

# %%
#remove redundant weather columns
colstodrop = ['OriginmaxtempC', 'OriginmintempC',
       'Origintotalsnow_cm', 'Originsunhour', 'OriginfeelslikeC',
       'OriginheatindexC', 'OriginwindchillC', 'OriginwindgustKmph',
       'Origincloudcover', 'Originhumidity', 'OriginprecipMM', 'OrigintempC',
       'Originvisibility', 'OriginwindspeedKmph', 'DestinmaxtempC',
       'DestinmintempC', 'Destintotalsnow_cm', 'Destinsunhour',
       'DestinfeelslikeC', 'DestinheatindexC', 'DestinwindchillC',
       'DestinwindgustKmph', 'Destincloudcover', 'Destinhumidity',
       'DestinprecipMM', 'DestintempC', 'Destinvisibility',
       'DestinwindspeedKmph']


df_merged_final.drop(colstodrop,axis=1,inplace=True)

# %%
#Exporting CSV file with weather features to add more features
df_merged_final.to_csv('df_merged_final_weathermodified_test.csv')

# %%
df_merged_final
# Out:
#        Unnamed: 0    fl_date mkt_unique_carrier branded_code_share  \
# 0              14 2020-01-01                 WN                 WN
# 1              15 2020-01-01                 WN                 WN
# 2              16 2020-01-01                 WN                 WN
# 3              17 2020-01-01                 WN                 WN
# 4              21 2020-01-01                 WN                 WN
# ...           ...        ...                ...                ...
# 17765       15971 2020-01-01                 AS                 AS
# 17766       15956 2020-01-01                 AS                 AS
# 17767       15963 2020-01-01                 AS                 AS
# 17768       15958 2020-01-01                 AS                 AS
# 17769       18856 2020-01-01                 UA                 UA
#
#       mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 0              WN                3719                WN   N941WN
# 1              WN                4863                WN   N496WN
# 2              WN                4924                WN   N7732A
# 3              WN                5321                WN   N7863A
# 4              WN                4887                WN   N246LV
# ...           ...                 ...               ...      ...
# 17765          AS                  70                AS   N644AS
# 17766          AS                  64                AS   N622AS
# 17767          AS                  65                AS   N607AS
# 17768          AS                  64                AS   N622AS
# 17769          UA                 174                UA   N34282
#
#        op_carrier_fl_num  origin_airport_id  ... dup crs_elapsed_time  \
# 0                   3719              13931  ...   N               65
# 1                   4863              13931  ...   N               60
# 2                   4924              13931  ...   N               60
# 3                   5321              13931  ...   N               70
# 4                   4887              14027  ...   N              135
# ...                  ...                ...  ...  ..              ...
# 17765                 70              12523  ...   N               43
# 17766                 64              12523  ...   N               49
# 17767                 65              15841  ...   N               22
# 17768                 64              14256  ...   N               24
# 17769                174              12016  ...   N               41
#
#        flights distance Weather_origin  Weather_destin  Visibility_origin  \
# 0            1      159          clear           clear     highvisibility
# 1            1      159          clear           clear     highvisibility
# 2            1      159          clear           clear     highvisibility
# 3            1      159          clear           clear     highvisibility
# 4            1      883          clear           clear     highvisibility
# ...        ...      ...            ...             ...                ...
# 17765        1       95          storm           storm      lowvisibility
# 17766        1      123          storm       heavyrain      lowvisibility
# 17767        1       31      heavyrain       heavyrain      lowvisibility
# 17768        1       31      heavyrain       heavyrain      lowvisibility
# 17769        1      129          clear       heavyrain     highvisibility
#
#       Visibility_destin  windspeed_origin  windspeed_destin
# 0        highvisibility      lowwindspeed      lowwindspeed
# 1        highvisibility      lowwindspeed      lowwindspeed
# 2        highvisibility      lowwindspeed      lowwindspeed
# 3        highvisibility      lowwindspeed      lowwindspeed
# 4        highvisibility      lowwindspeed      lowwindspeed
# ...                 ...               ...               ...
# 17765     lowvisibility      lowwindspeed      lowwindspeed
# 17766     lowvisibility      lowwindspeed      lowwindspeed
# 17767     lowvisibility      lowwindspeed      lowwindspeed
# 17768     lowvisibility      lowwindspeed      lowwindspeed
# 17769    highvisibility      lowwindspeed     highwindspeed
#
# [17770 rows x 27 columns]
