# %%
import pandas as pd
import numpy as np
import pickle

# %%
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
#linear regression

# %%
pickle_out=open('df_withdummies.pickle',"rb")
df_withdummies=pickle.load(pickle_out)

# %%
df_withdummies
# Out:
#         origin_airport_id  dest_airport_id  crs_dep_time  crs_arr_time  \
# 0                   15380            11433           615           738
# 1                   15380            11433          1746          1906
# 2                   15380            11433          1746          1909
# 3                   15380            11433          1746          1909
# 4                   15380            11433          1746          1909
# ...                   ...              ...           ...           ...
# 715366              13029            11292           630           715
# 715367              13029            11292          1250          1326
# 715368              13029            11292           630           715
# 715369              12884            13930          1814          1831
# 715370              13230            13930           800           914
#
#         crs_elapsed_time  distance  delay mean_by_airline  year  Month  Day  \
# 0                   83.0     207.0               1.090909  2018      1    1
# 1                   80.0     207.0               1.090909  2018      1   13
# 2                   83.0     207.0               1.090909  2018      1   14
# 3                   83.0     207.0               1.090909  2018      1   15
# 4                   83.0     207.0               1.090909  2018      1   16
# ...                  ...       ...                    ...   ...    ...  ...
# 715366             105.0     423.0              28.500000  2019      1   29
# 715367              96.0     423.0              28.500000  2019      1   29
# 715368             105.0     423.0              28.500000  2019      1   31
# 715369              77.0     179.0              31.000000  2019      1   26
# 715370             134.0     594.0              13.000000  2019      1   30
#
#         ...  op_unique_carrier_OH  op_unique_carrier_OO  op_unique_carrier_PT  \
# 0       ...                     0                     0                     0
# 1       ...                     0                     0                     0
# 2       ...                     0                     0                     0
# 3       ...                     0                     0                     0
# 4       ...                     0                     0                     0
# ...     ...                   ...                   ...                   ...
# 715366  ...                     0                     0                     0
# 715367  ...                     0                     0                     0
# 715368  ...                     0                     0                     0
# 715369  ...                     0                     0                     0
# 715370  ...                     0                     0                     0
#
#         op_unique_carrier_QX  op_unique_carrier_UA  op_unique_carrier_VX  \
# 0                          0                     0                     0
# 1                          0                     0                     0
# 2                          0                     0                     0
# 3                          0                     0                     0
# 4                          0                     0                     0
# ...                      ...                   ...                   ...
# 715366                     0                     0                     0
# 715367                     0                     0                     0
# 715368                     0                     0                     0
# 715369                     0                     0                     0
# 715370                     0                     1                     0
#
#         op_unique_carrier_WN  op_unique_carrier_YV  op_unique_carrier_YX  \
# 0                          0                     0                     0
# 1                          0                     0                     0
# 2                          0                     0                     0
# 3                          0                     0                     0
# 4                          0                     0                     0
# ...                      ...                   ...                   ...
# 715366                     0                     0                     0
# 715367                     0                     0                     0
# 715368                     0                     0                     0
# 715369                     0                     0                     1
# 715370                     0                     0                     0
#
#         op_unique_carrier_ZW
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ...                      ...
# 715366                     0
# 715367                     0
# 715368                     0
# 715369                     0
# 715370                     0
#
# [715371 rows x 38 columns]

# %%
X=df_withdummies.drop('delay mean_by_airline',axis=1)
y=df_withdummies['delay mean_by_airline']

# %%
X_train,X_test,y_train, y_test=train_test_split(X,y,train_size=0.8,random_state=10)

# %%
X_train = sm.add_constant(X_train) # adding a constant
model = sm.OLS(y_train, X_train).fit()
predictions = model.predict(X_test) 

print_model = model.summary()
print(print_model)
# Out:
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     delay mean_by_airline   R-squared:                       0.393
# Model:                               OLS   Adj. R-squared:                  0.393
# Method:                    Least Squares   F-statistic:                 1.058e+04
# Date:                   Mon, 04 Jul 2022   Prob (F-statistic):               0.00
# Time:                           10:02:49   Log-Likelihood:            -1.9206e+06
# No. Observations:                 572296   AIC:                         3.841e+06
# Df Residuals:                     572260   BIC:                         3.842e+06
# Df Model:                             35
# Covariance Type:               nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# origin_airport_id    -7.894e-05   6.26e-06    -12.603      0.000   -9.12e-05   -6.67e-05
# dest_airport_id         -0.0001   6.25e-06    -21.117      0.000      -0.000      -0.000
# crs_dep_time            -0.0002   2.87e-05     -8.193      0.000      -0.000      -0.000
# crs_arr_time             0.0003   2.75e-05     11.771      0.000       0.000       0.000
# crs_elapsed_time         0.0176      0.001     35.006      0.000       0.017       0.019
# distance                -0.0030   6.41e-05    -46.284      0.000      -0.003      -0.003
# year                     0.1926      0.018     10.452      0.000       0.157       0.229
# Month                 -367.9456     35.922    -10.243      0.000    -438.352    -297.540
# Day                     -0.0056      0.001     -4.308      0.000      -0.008      -0.003
# op_unique_carrier_9E   -14.6340      1.285    -11.386      0.000     -17.153     -12.115
# op_unique_carrier_9K   -22.1274      1.374    -16.110      0.000     -24.819     -19.435
# op_unique_carrier_AA   -17.0877      1.284    -13.307      0.000     -19.605     -14.571
# op_unique_carrier_AS   -22.2833      1.286    -17.329      0.000     -24.804     -19.763
# op_unique_carrier_AX    -1.1526      1.285     -0.897      0.370      -3.671       1.366
# op_unique_carrier_B6    -6.5936      1.284     -5.135      0.000      -9.110      -4.077
# op_unique_carrier_C5     9.3065      1.291      7.211      0.000       6.777      11.836
# op_unique_carrier_CP   -17.1896      1.287    -13.360      0.000     -19.711     -14.668
# op_unique_carrier_DL   -19.0311      1.284    -14.820      0.000     -21.548     -16.514
# op_unique_carrier_EM   -20.0625      1.338    -14.991      0.000     -22.686     -17.439
# op_unique_carrier_EV    -8.7800      1.283     -6.843      0.000     -11.295      -6.265
# op_unique_carrier_F9   -10.8915      1.285     -8.474      0.000     -13.411      -8.372
# op_unique_carrier_G4   -11.6257      1.286     -9.040      0.000     -14.146      -9.105
# op_unique_carrier_G7    -6.3364      1.286     -4.929      0.000      -8.856      -3.817
# op_unique_carrier_HA   -18.1853      1.286    -14.139      0.000     -20.706     -15.664
# op_unique_carrier_KS    -3.7132      1.413     -2.628      0.009      -6.483      -0.944
# op_unique_carrier_MQ    -6.2071      1.285     -4.829      0.000      -8.726      -3.688
# op_unique_carrier_NK   -16.6713      1.285    -12.973      0.000     -19.190     -14.153
# op_unique_carrier_OH   -13.0389      1.285    -10.149      0.000     -15.557     -10.521
# op_unique_carrier_OO    -8.0088      1.284     -6.238      0.000     -10.525      -5.492
# op_unique_carrier_PT   -18.3433      1.287    -14.255      0.000     -20.865     -15.821
# op_unique_carrier_QX   -19.4291      1.286    -15.107      0.000     -21.950     -16.908
# op_unique_carrier_UA   -16.6073      1.284    -12.932      0.000     -19.124     -14.090
# op_unique_carrier_VX   -25.5712      1.280    -19.972      0.000     -28.081     -23.062
# op_unique_carrier_WN   -19.7415      1.284    -15.378      0.000     -22.258     -17.225
# op_unique_carrier_YV   -15.1012      1.286    -11.747      0.000     -17.621     -12.582
# op_unique_carrier_YX   -12.7239      1.284     -9.907      0.000     -15.241     -10.207
# op_unique_carrier_ZW    -6.1146      1.285     -4.757      0.000      -8.634      -3.595
# ==============================================================================
# Omnibus:                   521404.992   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        358957739.885
# Skew:                           3.403   Prob(JB):                         0.00
# Kurtosis:                     125.503   Cond. No.                     1.41e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.62e-19. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
#RF
from sklearn.ensemble import RandomForestRegressor
